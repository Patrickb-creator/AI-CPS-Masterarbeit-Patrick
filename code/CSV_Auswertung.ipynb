# %%
import pandas as pd

df = pd.read_csv('C:/Users/Patrick/Desktop/Masterarbeit/Code_Patrick/AI-CPS-Masterarbeit-Patrick/code/taskManager/power_logs_green/2025-05-21 15-52-50_power-log-random_18.csv')

df.head(30)
# Out:
#    client_id  total_power_usage       kwh  \
# 0     764045         382.258092  0.000106
# 1     835230        6088.617033  0.001691
# 2          0        6470.875125  0.001797
# 3     764045         343.307218  0.000095
# 4     835230        4735.449149  0.001315
# 5          0        5078.756367  0.001411
# 6     764045         433.950216  0.000121
# 7     835230        3443.747225  0.000957
# 8          0        3877.697441  0.001077
#
#                                relevant_power_values  num_of_power_values  \
# 0  [41.4, 41.4, 41.4, 26.1, 26.1, 41.9, 41.9, 28....                   24
# 1  [88.0, 88.0, 88.0, 100.2, 100.2, 90.4, 90.4, 7...                   58
# 2                                                NaN                   82
# 3  [32.4, 32.4, 35.2, 35.2, 35.2, 29.4, 29.4, 29....                   19
# 4  [148.9, 148.9, 142.1, 139.9, 139.9, 132.2, 132...                   31
# 5                                                NaN                   50
# ...

# %%
df_2 = pd.read_csv('C:/Users/Patrick/Desktop/Masterarbeit/Code_Patrick/AI-CPS-Masterarbeit-Patrick/code/taskManager/power_logs_green/2025-05-24 20-26-33_power-log-random_4.csv')

df_2.head(30)
# Out:
#    round  client_id  scenario  total_power_usage       kwh  \
# 0    NaN     835230       NaN        2756.174980  0.000766
# 1    NaN          0       NaN        2756.174980  0.000766
# 2    NaN     835230       NaN        2594.542594  0.000721
# 3    NaN          0       NaN        2594.542594  0.000721
#
#                                relevant_power_values  num_of_power_values  \
# 0  [90.0, 90.0, 94.4, 86.9, 78.7, 78.7, 79.7, 103...                   32
# 1                                                NaN                   32
# 2  [147.7, 147.7, 147.7, 131.1, 131.1, 131.3, 141...                   12
# 3                                                NaN                   12
#
#    tasks_assigned  efficiency_per_task   efficiency  total_duration  \
# 0               2             0.000383  2612.316000       24.513633
# 1               2             0.000383  2612.316000       24.513633
# 2               2             0.000360  2775.055617       18.748953
# ...

# %%
df_3 = pd.read_csv('C:/Users/Patrick/Desktop/Masterarbeit/Code_Patrick/AI-CPS-Masterarbeit-Patrick/code/taskManager/power_logs_green/2025-05-24 22-27-53_power-log-random_4.csv')

df_3.head(30)
# Out:
#    round  client_id scenario  total_power_usage       kwh  \
# 0    1.0     835230    apply        1444.049412  0.000401
# 1    1.0     835230    apply        2443.262101  0.000679
# 2    NaN          0      NaN        2443.262101  0.000679
# 3    2.0     835230    apply        1204.250464  0.000335
# 4    2.0     835230    apply        2521.668487  0.000700
# 5    NaN          0      NaN        2521.668487  0.000700
#
#                                relevant_power_values  num_of_power_values  \
# 0  [85.7, 85.7, 100.2, 100.2, 100.2, 87.3, 87.3, ...                   16
# 1  [85.7, 85.7, 100.2, 100.2, 100.2, 87.3, 87.3, ...                   29
# 2                                                NaN                   29
# 3  [129.0, 129.0, 129.0, 119.9, 119.9, 119.9, 130...                    9
# 4  [129.0, 129.0, 129.0, 119.9, 119.9, 119.9, 130...                   20
# 5                                                NaN                   20
#
# ...

# %%
df_4 = pd.read_csv('C:/Users/Patrick/Desktop/Masterarbeit/Code_Patrick/AI-CPS-Masterarbeit-Patrick/code/taskManager/power_logs_green/2025-05-24 22-32-25_power-log-random_6.csv')

df_4.head(30)
# Out:
#    round  client_id scenario  total_power_usage       kwh  \
# 0    1.0     835230    apply        1420.608174  0.000395
# 1    1.0     835230    apply        2431.216250  0.000675
# 2    NaN          0      NaN        2431.216250  0.000675
# 3    2.0     835230    apply        1166.016039  0.000324
# 4    2.0     835230    apply        2566.120854  0.000713
# 5    NaN          0      NaN        2566.120854  0.000713
# 6    3.0     835230    apply        1256.604690  0.000349
# 7    3.0     835230    apply        2524.409433  0.000701
# 8    NaN          0      NaN        2524.409433  0.000701
#
#                                relevant_power_values  num_of_power_values  \
# 0  [75.7, 75.7, 95.3, 95.3, 92.1, 80.0, 80.0, 80....                   16
# 1  [75.7, 75.7, 95.3, 95.3, 92.1, 80.0, 80.0, 80....                   30
# 2                                                NaN                   30
# 3  [114.7, 114.7, 135.1, 135.1, 132.5, 117.8, 117...                   11
# ...
